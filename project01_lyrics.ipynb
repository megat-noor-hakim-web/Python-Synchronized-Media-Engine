# %%
import webbrowser
webbrowser.open("https://youtu.be/YQk9Wc20y1c")

import time

# Colour codes
RED = "\033[31m"
GREEN = "\033[32m"
YELLOW = "\033[33m"
BLUE = "\033[34m"
MAGENTA = "\033[35m"
CYAN = "\033[36m"
RESET = "\033[0m"

def system_typewriter(line, letter_delay=0.05, colour=RESET):
    for letter in line:
        print(colour + letter + RESET, end="", flush=True)
        time.sleep(letter_delay)
    print()

def lyrics_settings(lyrics, letter_delay=0.05, colour=RESET):
    for sentence, gap in lyrics:
        system_typewriter(sentence, letter_delay, colour)
        time.sleep(gap)

# First paragraph
verse1 = [
    ("__________________________________________________", 16.5),
    ("I know you've got the best intentions...", 2.7),
    ("Just trynna find the right words to say...", 3.3),
    ("I promised I've already learnt my lesson...", 3.0),
    ("But right now...I wanna be not okay...", 0.0)
]

# Second paragraph
verse2 = [
    ("So tired, sittin here waiting...", 0.55),
    ("If I hear one more 'Just be patient'", 1.4),
    ("It's always gonna stay the same...", 0.0)
 ]

# Third paragraph
chorus = [
    ("So let me just give up...", 1.2),
    ("So let me just let go...", 1.5),
    ("If this isn't good for me", 1.2),
    ("Well, I don't wanna know...", 1.2),
    ("Let me just stop trying...", 1.5),
    ("Let me just stop fighting...", 1.5),
    ("I don't want your good advice, reasons why I'm alright...", 0.00)
]

# Fourth paragraph
verse3 = [
    ("You don't know what it's like...", 1.4),
    ("You don't know what it's like...", 0.0)
]

# Fifth paragraph
verse4 = [
    ("Can't stop this feet from sinkin...", 3.6),
    ("And it's starting to show on me...", 3.9),
    ("You staring while I'm blinking...", 3.5),
    ("But just don't tell me what you see...", 0.0)
]

# Sixth paragraph
verse5 = [
    ("I'm so over all this bad luck...", 0.1),
    ("Hearing one more 'Keep your head up'...", 2.0),
    ("Is it ever gonna change?", 0.0)
]

# Seventh paragraph

verse6 = [
    ("Don't look at me like that", 1.5),
    ("Just like you understand...", 1.4),
    ("Don't try to pull me back...", 0.0)
]

verse7 = [
    ("You don't know", 0.8),
    ("you DON'T know", 0.8),
    ("YOU DON'T KNOW", 0.8),
    ("You don't know what it's like...", 0.8),
    ("you don't know what it's like...", 0.8),
    ("you don't know...you don't know...", 0.8),
    ("you don't know what it's like...", 0.8),
    ("you don't know what it's like...", 0.0)
]

# Output syntax
lyrics_settings(verse1, letter_delay=0.05)
print()
time.sleep(3.5)
lyrics_settings(verse2, letter_delay=0.05, colour=BLUE)
print()
time.sleep(1.6)
lyrics_settings(chorus, letter_delay=0.05, colour=MAGENTA)
print()
time.sleep(2.0)
lyrics_settings(verse3, letter_delay=0.05)
print()
time.sleep(8.5)
lyrics_settings(verse4, letter_delay=0.05, colour=CYAN)
print()
time.sleep(3.5)
lyrics_settings(verse5, letter_delay=0.05, colour=GREEN)
print()
time.sleep(2.0)
lyrics_settings(chorus, letter_delay=0.05, colour=MAGENTA)
print()
time.sleep(2.0)
lyrics_settings(verse3, letter_delay=0.05)
print()
time.sleep(20.0)
lyrics_settings(verse6, letter_delay=0.05, colour=YELLOW)
print()
time.sleep(2.0)
lyrics_settings(chorus, letter_delay=0.05, colour=MAGENTA)
print()
time.sleep(2.0)
lyrics_settings(verse3, letter_delay=0.05)
print()
time.sleep(1.8)
lyrics_settings(verse7, letter_delay=0.05, colour=RED)
# Out:
# __________________________________________________
# I know you've got the best intentions...
# Just trynna find the right words to say...
# I promised I've already learnt my lesson...
# But right now...I wanna be not okay...
#
# So tired, sittin here waiting...
# If I hear one more 'Just be patient'
# It's always gonna stay the same...
#
# So let me just give up...
# So let me just let go...
# If this isn't good for me
# Well, I don't wanna know...
# Let me just stop trying...
# Let me just stop fighting...
# I don't want your good advice, reasons why I'm alright...
#
# You don't know what it's like...
# You don't know what it's like...
#
# Can't stop this feet from sinkin...
# And it's starting to show on me...
# You staring while I'm blinking...
# But just don't tell me what you see...
#
# I'm so over all this bad luck...
# Hearing one more 'Keep your head up'...
# Is it ever gonna change?
#
# So let me just give up...
# So let me just let go...
# If this isn't good for me
# ...
